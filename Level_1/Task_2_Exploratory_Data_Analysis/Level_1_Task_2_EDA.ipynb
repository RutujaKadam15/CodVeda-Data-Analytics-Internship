# %% [markdown]
# # Level 1 - Task 2: Exploratory Data Analysis (EDA)

# %% [markdown]
# # Level 1 - Task 2: Exploratory Data Analysis (EDA)
#
# ### Objective
#
# The objective of this task is to perform exploratory data analysis (EDA) on the Iris dataset by understanding its structure, generating summary statistics, visualizing data distributions, identifying outliers, and analyzing relationships between variables using Python, Pandas, Matplotlib, and Seaborn.

# %% [markdown]
# ## Import the Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # load cleaned dataset

# %%
df = pd.read_csv("iris_cleaned.csv")

# %% [markdown]
# # diplay first five rows

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (147, 5)

# %% [markdown]
# ## Plot Histograms
#
# A histogram is used to visualize the distribution of numerical features in the dataset. It helps us understand the frequency, spread, and shape of the data.

# %%
df.hist(figsize=(10, 8))
plt.suptitle("Distribution of Iris Dataset Features")
plt.show()

# %% [markdown]
# ## Create Box Plots
#
# Box plots help identify the distribution of numerical features and detect potential outliers in the dataset.

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.title("Box Plot of Iris Dataset Features")
plt.show()

# %% [markdown]
# ## Create a Scatter Plot
#
# A scatter plot is used to visualize the relationship between two numerical features. It helps identify patterns, trends, and the separation between different species.

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    data=df,
    x="petal_length",
    y="petal_width",
    hue="species"
)

plt.title("Petal Length vs Petal Width")
plt.show()

# %% [markdown]
# ## Correlation Heatmap
#
# A correlation heatmap shows the relationship between numerical features. Correlation values range from -1 to +1, where values closer to +1 indicate a strong positive relationship, values closer to -1 indicate a strong negative relationship, and values near 0 indicate little or no relationship.

# %%
plt.figure(figsize=(8,6))

correlation = df.select_dtypes(include=['number']).corr()

sns.heatmap(correlation, annot=True, cmap="Blues")

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Conclusion
#
# From the exploratory data analysis of the Iris dataset, the following observations were made:
#
# - The dataset is clean and contains no missing values.
# - Sepal Width contains a few outliers, while the other numerical features have very few or no significant outliers.
# - Petal Length and Petal Width show a strong positive correlation.
# - The scatter plot clearly separates the three Iris species based on petal measurements.
# - Histograms show the distribution of each numerical feature.
# - Overall, the dataset is well-structured and suitable for machine learning and classification tasks.
